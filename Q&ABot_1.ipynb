# %% [markdown]
# <a href="https://colab.research.google.com/github/kitty57/DocQ-A/blob/master/Q%26ABot_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -q cassandra-driver
# !pip install -q cassio>=0.1.1
# !pip install -q gradientai --upgrade
# !pip install -q llama-index
# !pip install -q pypdf
# !pip install -q tiktoken==0.4.0
# !pip install --upgrade astrapy
# Out:
# Requirement already satisfied: astrapy in /usr/local/lib/python3.10/dist-packages (0.7.6)
# Requirement already satisfied: cassio<0.2.0,>=0.1.4 in /usr/local/lib/python3.10/dist-packages (from astrapy) (0.1.5)
# Requirement already satisfied: deprecation<2.2.0,>=2.1.0 in /usr/local/lib/python3.10/dist-packages (from astrapy) (2.1.0)
# Requirement already satisfied: httpx[http2]<1,>=0.25.2 in /usr/local/lib/python3.10/dist-packages (from astrapy) (0.27.0)
# Requirement already satisfied: toml<0.11.0,>=0.10.2 in /usr/local/lib/python3.10/dist-packages (from astrapy) (0.10.2)
# Requirement already satisfied: cassandra-driver>=3.28.0 in /usr/local/lib/python3.10/dist-packages (from cassio<0.2.0,>=0.1.4->astrapy) (3.29.0)
# Requirement already satisfied: numpy>=1.0 in /usr/local/lib/python3.10/dist-packages (from cassio<0.2.0,>=0.1.4->astrapy) (1.26.4)
# Requirement already satisfied: requests>=2 in /usr/local/lib/python3.10/dist-packages (from cassio<0.2.0,>=0.1.4->astrapy) (2.31.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from deprecation<2.2.0,>=2.1.0->astrapy) (23.2)
# Requirement already satisfied: anyio in /usr/local/lib/python3.10/dist-packages (from httpx[http2]<1,>=0.25.2->astrapy) (4.3.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from httpx[http2]<1,>=0.25.2->astrapy) (2024.2.2)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.10/dist-packages (from httpx[http2]<1,>=0.25.2->astrapy) (1.0.4)
# Requirement already satisfied: idna in /usr/local/lib/python3.10/dist-packages (from httpx[http2]<1,>=0.25.2->astrapy) (3.6)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from httpx[http2]<1,>=0.25.2->astrapy) (1.3.0)
# Requirement already satisfied: h2<5,>=3 in /usr/local/lib/python3.10/dist-packages (from httpx[http2]<1,>=0.25.2->astrapy) (4.1.0)
# Requirement already satisfied: h11<0.15,>=0.13 in /usr/local/lib/python3.10/dist-packages (from httpcore==1.*->httpx[http2]<1,>=0.25.2->astrapy) (0.14.0)
# Requirement already satisfied: geomet<0.3,>=0.1 in /usr/local/lib/python3.10/dist-packages (from cassandra-driver>=3.28.0->cassio<0.2.0,>=0.1.4->astrapy) (0.2.1.post1)
# Requirement already satisfied: hyperframe<7,>=6.0 in /usr/local/lib/python3.10/dist-packages (from h2<5,>=3->httpx[http2]<1,>=0.25.2->astrapy) (6.0.1)
# Requirement already satisfied: hpack<5,>=4.0 in /usr/local/lib/python3.10/dist-packages (from h2<5,>=3->httpx[http2]<1,>=0.25.2->astrapy) (4.0.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2->cassio<0.2.0,>=0.1.4->astrapy) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2->cassio<0.2.0,>=0.1.4->astrapy) (2.2.1)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /usr/local/lib/python3.10/dist-packages (from anyio->httpx[http2]<1,>=0.25.2->astrapy) (1.2.0)
# Requirement already satisfied: typing-extensions>=4.1 in /usr/local/lib/python3.10/dist-packages (from anyio->httpx[http2]<1,>=0.25.2->astrapy) (4.9.0)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from geomet<0.3,>=0.1->cassandra-driver>=3.28.0->cassio<0.2.0,>=0.1.4->astrapy) (8.1.7)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from geomet<0.3,>=0.1->cassandra-driver>=3.28.0->cassio<0.2.0,>=0.1.4->astrapy) (1.16.0)

# %%
import os
import json
from google.colab import userdata

# %%
from google.colab import userdata

# %%
os.environ['GRADIENT_ACCESS_TOKEN'] = userdata.get('GRADIENT_ACCESS_TOKEN')
os.environ['GRADIENT_WORKSPACE_ID'] = userdata.get('GRADIENT_WORKSPACE_ID')

# %%
import sys

if 'llama-index' in sys.modules:
    print("llama_index is installed.")
    import llama_index
    print("Available version:", llama_index)  # If this doesn't work, try just `print(llama_index)` to see if any output is printed.
else:
    print("llama_index is not installed.")
# Out:
# llama_index is not installed.

# %%
sys.executable
# Out:
# '/usr/bin/python3'

# %%
# !pip install --upgrade --force-reinstall llama-index
# Out:
# Collecting llama-index
#   Using cached llama_index-0.10.12-py3-none-any.whl (5.6 kB)
# Collecting llama-index-agent-openai<0.2.0,>=0.1.4 (from llama-index)
#   Using cached llama_index_agent_openai-0.1.5-py3-none-any.whl (12 kB)
# Collecting llama-index-cli<0.2.0,>=0.1.2 (from llama-index)
#   Using cached llama_index_cli-0.1.5-py3-none-any.whl (25 kB)
# Collecting llama-index-core<0.11.0,>=0.10.12 (from llama-index)
#   Using cached llama_index_core-0.10.12-py3-none-any.whl (15.3 MB)
# Collecting llama-index-embeddings-openai<0.2.0,>=0.1.5 (from llama-index)
#   Using cached llama_index_embeddings_openai-0.1.6-py3-none-any.whl (6.0 kB)
# Collecting llama-index-indices-managed-llama-cloud<0.2.0,>=0.1.2 (from llama-index)
#   Using cached llama_index_indices_managed_llama_cloud-0.1.3-py3-none-any.whl (6.6 kB)
# Collecting llama-index-legacy<0.10.0,>=0.9.48 (from llama-index)
#   Using cached llama_index_legacy-0.9.48-py3-none-any.whl (2.0 MB)
# Collecting llama-index-llms-openai<0.2.0,>=0.1.5 (from llama-index)
#   Using cached llama_index_llms_openai-0.1.6-py3-none-any.whl (9.4 kB)
# Collecting llama-index-multi-modal-llms-openai<0.2.0,>=0.1.3 (from llama-index)
#   Using cached llama_index_multi_modal_llms_openai-0.1.4-py3-none-any.whl (5.8 kB)
# Collecting llama-index-program-openai<0.2.0,>=0.1.3 (from llama-index)
#   Using cached llama_index_program_openai-0.1.4-py3-none-any.whl (4.1 kB)
# Collecting llama-index-question-gen-openai<0.2.0,>=0.1.2 (from llama-index)
#   Using cached llama_index_question_gen_openai-0.1.3-py3-none-any.whl (2.9 kB)
# Collecting llama-index-readers-file<0.2.0,>=0.1.4 (from llama-index)
#   Using cached llama_index_readers_file-0.1.5-py3-none-any.whl (33 kB)
# Collecting llama-index-readers-llama-parse<0.2.0,>=0.1.2 (from llama-index)
#   Using cached llama_index_readers_llama_parse-0.1.3-py3-none-any.whl (2.5 kB)
# Collecting llama-index-vector-stores-chroma<0.2.0,>=0.1.1 (from llama-index-cli<0.2.0,>=0.1.2->llama-index)
#   Using cached llama_index_vector_stores_chroma-0.1.4-py3-none-any.whl (4.5 kB)
# Collecting PyYAML>=6.0.1 (from llama-index-core<0.11.0,>=0.10.12->llama-index)
#   Downloading PyYAML-6.0.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (705 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 705.5/705.5 kB 11.1 MB/s eta 0:00:00
# Collecting SQLAlchemy[asyncio]>=1.4.49 (from llama-index-core<0.11.0,>=0.10.12->llama-index)
#   Downloading SQLAlchemy-2.0.27-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 23.4 MB/s eta 0:00:00
# Collecting aiohttp<4.0.0,>=3.8.6 (from llama-index-core<0.11.0,>=0.10.12->llama-index)
#   Downloading aiohttp-3.9.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 33.6 MB/s eta 0:00:00
# Collecting dataclasses-json (from llama-index-core<0.11.0,>=0.10.12->llama-index)
#   Using cached dataclasses_json-0.6.4-py3-none-any.whl (28 kB)
# Collecting deprecated>=1.2.9.3 (from llama-index-core<0.11.0,>=0.10.12->llama-index)
#   Using cached Deprecated-1.2.14-py2.py3-none-any.whl (9.6 kB)
# Collecting dirtyjson<2.0.0,>=1.0.8 (from llama-index-core<0.11.0,>=0.10.12->llama-index)
#   Using cached dirtyjson-1.0.8-py3-none-any.whl (25 kB)
# Collecting fsspec>=2023.5.0 (from llama-index-core<0.11.0,>=0.10.12->llama-index)
#   Downloading fsspec-2024.2.0-py3-none-any.whl (170 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 170.9/170.9 kB 23.0 MB/s eta 0:00:00
# Collecting httpx (from llama-index-core<0.11.0,>=0.10.12->llama-index)
#   Using cached httpx-0.27.0-py3-none-any.whl (75 kB)
# Collecting llamaindex-py-client<0.2.0,>=0.1.13 (from llama-index-core<0.11.0,>=0.10.12->llama-index)
#   Using cached llamaindex_py_client-0.1.13-py3-none-any.whl (107 kB)
# Collecting nest-asyncio<2.0.0,>=1.5.8 (from llama-index-core<0.11.0,>=0.10.12->llama-index)
#   Downloading nest_asyncio-1.6.0-py3-none-any.whl (5.2 kB)
# Collecting networkx>=3.0 (from llama-index-core<0.11.0,>=0.10.12->llama-index)
#   Downloading networkx-3.2.1-py3-none-any.whl (1.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 40.0 MB/s eta 0:00:00
# Collecting nltk<4.0.0,>=3.8.1 (from llama-index-core<0.11.0,>=0.10.12->llama-index)
#   Downloading nltk-3.8.1-py3-none-any.whl (1.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 47.8 MB/s eta 0:00:00
# Collecting numpy (from llama-index-core<0.11.0,>=0.10.12->llama-index)
#   Downloading numpy-1.26.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (18.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.2/18.2 MB 48.9 MB/s eta 0:00:00
# Collecting openai>=1.1.0 (from llama-index-core<0.11.0,>=0.10.12->llama-index)
#   Using cached openai-1.12.0-py3-none-any.whl (226 kB)
# Collecting pandas (from llama-index-core<0.11.0,>=0.10.12->llama-index)
#   Downloading pandas-2.2.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (13.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.0/13.0 MB 67.8 MB/s eta 0:00:00
# Collecting pillow>=9.0.0 (from llama-index-core<0.11.0,>=0.10.12->llama-index)
#   Downloading pillow-10.2.0-cp310-cp310-manylinux_2_28_x86_64.whl (4.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 61.6 MB/s eta 0:00:00
# Collecting requests>=2.31.0 (from llama-index-core<0.11.0,>=0.10.12->llama-index)
#   Downloading requests-2.31.0-py3-none-any.whl (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.6/62.6 kB 8.2 MB/s eta 0:00:00
# Collecting tenacity<9.0.0,>=8.2.0 (from llama-index-core<0.11.0,>=0.10.12->llama-index)
#   Downloading tenacity-8.2.3-py3-none-any.whl (24 kB)
# Collecting tiktoken>=0.3.3 (from llama-index-core<0.11.0,>=0.10.12->llama-index)
#   Using cached tiktoken-0.6.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.8 MB)
# Collecting tqdm<5.0.0,>=4.66.1 (from llama-index-core<0.11.0,>=0.10.12->llama-index)
#   Downloading tqdm-4.66.2-py3-none-any.whl (78 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.3/78.3 kB 10.9 MB/s eta 0:00:00
# Collecting typing-extensions>=4.5.0 (from llama-index-core<0.11.0,>=0.10.12->llama-index)
#   Downloading typing_extensions-4.9.0-py3-none-any.whl (32 kB)
# Collecting typing-inspect>=0.8.0 (from llama-index-core<0.11.0,>=0.10.12->llama-index)
#   Using cached typing_inspect-0.9.0-py3-none-any.whl (8.8 kB)
# Collecting beautifulsoup4<5.0.0,>=4.12.3 (from llama-index-readers-file<0.2.0,>=0.1.4->llama-index)
#   Downloading beautifulsoup4-4.12.3-py3-none-any.whl (147 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 147.9/147.9 kB 21.2 MB/s eta 0:00:00
# Collecting bs4<0.0.3,>=0.0.2 (from llama-index-readers-file<0.2.0,>=0.1.4->llama-index)
#   Using cached bs4-0.0.2-py2.py3-none-any.whl (1.2 kB)
# Collecting pymupdf<2.0.0,>=1.23.21 (from llama-index-readers-file<0.2.0,>=0.1.4->llama-index)
#   Using cached PyMuPDF-1.23.25-cp310-none-manylinux2014_x86_64.whl (4.4 MB)
# Collecting pypdf<5.0.0,>=4.0.1 (from llama-index-readers-file<0.2.0,>=0.1.4->llama-index)
#   Using cached pypdf-4.0.2-py3-none-any.whl (283 kB)
# Collecting llama-parse<0.4.0,>=0.3.3 (from llama-index-readers-llama-parse<0.2.0,>=0.1.2->llama-index)
#   Using cached llama_parse-0.3.4-py3-none-any.whl (5.3 kB)
# Collecting aiosignal>=1.1.2 (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.11.0,>=0.10.12->llama-index)
#   Downloading aiosignal-1.3.1-py3-none-any.whl (7.6 kB)
# Collecting attrs>=17.3.0 (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.11.0,>=0.10.12->llama-index)
#   Downloading attrs-23.2.0-py3-none-any.whl (60 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.8/60.8 kB 6.8 MB/s eta 0:00:00
# Collecting frozenlist>=1.1.1 (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.11.0,>=0.10.12->llama-index)
#   Downloading frozenlist-1.4.1-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (239 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 239.5/239.5 kB 29.0 MB/s eta 0:00:00
# Collecting multidict<7.0,>=4.5 (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.11.0,>=0.10.12->llama-index)
#   Downloading multidict-6.0.5-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (124 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.3/124.3 kB 1.3 MB/s eta 0:00:00
# Collecting yarl<2.0,>=1.0 (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.11.0,>=0.10.12->llama-index)
#   Downloading yarl-1.9.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (301 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 301.6/301.6 kB 33.7 MB/s eta 0:00:00
# Collecting async-timeout<5.0,>=4.0 (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.11.0,>=0.10.12->llama-index)
#   Downloading async_timeout-4.0.3-py3-none-any.whl (5.7 kB)
# Collecting soupsieve>1.2 (from beautifulsoup4<5.0.0,>=4.12.3->llama-index-readers-file<0.2.0,>=0.1.4->llama-index)
#   Downloading soupsieve-2.5-py3-none-any.whl (36 kB)
# Collecting wrapt<2,>=1.10 (from deprecated>=1.2.9.3->llama-index-core<0.11.0,>=0.10.12->llama-index)
#   Downloading wrapt-1.16.0-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (80 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 80.3/80.3 kB 11.3 MB/s eta 0:00:00
# Collecting chromadb<0.5.0,>=0.4.22 (from llama-index-vector-stores-chroma<0.2.0,>=0.1.1->llama-index-cli<0.2.0,>=0.1.2->llama-index)
#   Using cached chromadb-0.4.23-py3-none-any.whl (521 kB)
# Collecting onnxruntime<2.0.0,>=1.17.0 (from llama-index-vector-stores-chroma<0.2.0,>=0.1.1->llama-index-cli<0.2.0,>=0.1.2->llama-index)
#   Using cached onnxruntime-1.17.0-cp310-cp310-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (6.8 MB)
# Collecting tokenizers<0.16.0,>=0.15.1 (from llama-index-vector-stores-chroma<0.2.0,>=0.1.1->llama-index-cli<0.2.0,>=0.1.2->llama-index)
#   Downloading tokenizers-0.15.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.6/3.6 MB 83.8 MB/s eta 0:00:00
# Collecting pydantic>=1.10 (from llamaindex-py-client<0.2.0,>=0.1.13->llama-index-core<0.11.0,>=0.10.12->llama-index)
#   Downloading pydantic-2.6.1-py3-none-any.whl (394 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 394.8/394.8 kB 41.5 MB/s eta 0:00:00
# Collecting anyio (from httpx->llama-index-core<0.11.0,>=0.10.12->llama-index)
#   Downloading anyio-4.3.0-py3-none-any.whl (85 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.6/85.6 kB 12.3 MB/s eta 0:00:00
# Collecting certifi (from httpx->llama-index-core<0.11.0,>=0.10.12->llama-index)
#   Downloading certifi-2024.2.2-py3-none-any.whl (163 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 163.8/163.8 kB 19.5 MB/s eta 0:00:00
# Collecting httpcore==1.* (from httpx->llama-index-core<0.11.0,>=0.10.12->llama-index)
#   Using cached httpcore-1.0.4-py3-none-any.whl (77 kB)
# Collecting idna (from httpx->llama-index-core<0.11.0,>=0.10.12->llama-index)
#   Downloading idna-3.6-py3-none-any.whl (61 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.6/61.6 kB 8.9 MB/s eta 0:00:00
# Collecting sniffio (from httpx->llama-index-core<0.11.0,>=0.10.12->llama-index)
#   Downloading sniffio-1.3.0-py3-none-any.whl (10 kB)
# Collecting h11<0.15,>=0.13 (from httpcore==1.*->httpx->llama-index-core<0.11.0,>=0.10.12->llama-index)
#   Using cached h11-0.14.0-py3-none-any.whl (58 kB)
# Collecting click (from nltk<4.0.0,>=3.8.1->llama-index-core<0.11.0,>=0.10.12->llama-index)
#   Downloading click-8.1.7-py3-none-any.whl (97 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 97.9/97.9 kB 13.9 MB/s eta 0:00:00
# Collecting joblib (from nltk<4.0.0,>=3.8.1->llama-index-core<0.11.0,>=0.10.12->llama-index)
#   Downloading joblib-1.3.2-py3-none-any.whl (302 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 302.2/302.2 kB 36.5 MB/s eta 0:00:00
# Collecting regex>=2021.8.3 (from nltk<4.0.0,>=3.8.1->llama-index-core<0.11.0,>=0.10.12->llama-index)
#   Downloading regex-2023.12.25-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (773 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 774.0/774.0 kB 7.5 MB/s eta 0:00:00
# Collecting distro<2,>=1.7.0 (from openai>=1.1.0->llama-index-core<0.11.0,>=0.10.12->llama-index)
#   Downloading distro-1.9.0-py3-none-any.whl (20 kB)
# Collecting PyMuPDFb==1.23.22 (from pymupdf<2.0.0,>=1.23.21->llama-index-readers-file<0.2.0,>=0.1.4->llama-index)
#   Using cached PyMuPDFb-1.23.22-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (30.6 MB)
# Collecting charset-normalizer<4,>=2 (from requests>=2.31.0->llama-index-core<0.11.0,>=0.10.12->llama-index)
#   Downloading charset_normalizer-3.3.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (142 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 142.1/142.1 kB 16.6 MB/s eta 0:00:00
# Collecting urllib3<3,>=1.21.1 (from requests>=2.31.0->llama-index-core<0.11.0,>=0.10.12->llama-index)
#   Downloading urllib3-2.2.1-py3-none-any.whl (121 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.1/121.1 kB 14.9 MB/s eta 0:00:00
# Collecting greenlet!=0.4.17 (from SQLAlchemy[asyncio]>=1.4.49->llama-index-core<0.11.0,>=0.10.12->llama-index)
#   Downloading greenlet-3.0.3-cp310-cp310-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (616 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 616.0/616.0 kB 42.8 MB/s eta 0:00:00
# Collecting mypy-extensions>=0.3.0 (from typing-inspect>=0.8.0->llama-index-core<0.11.0,>=0.10.12->llama-index)
#   Using cached mypy_extensions-1.0.0-py3-none-any.whl (4.7 kB)
# Collecting marshmallow<4.0.0,>=3.18.0 (from dataclasses-json->llama-index-core<0.11.0,>=0.10.12->llama-index)
#   Using cached marshmallow-3.20.2-py3-none-any.whl (49 kB)
# Collecting python-dateutil>=2.8.2 (from pandas->llama-index-core<0.11.0,>=0.10.12->llama-index)
#   Downloading python_dateutil-2.8.2-py2.py3-none-any.whl (247 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 247.7/247.7 kB 27.0 MB/s eta 0:00:00
# Collecting pytz>=2020.1 (from pandas->llama-index-core<0.11.0,>=0.10.12->llama-index)
#   Downloading pytz-2024.1-py2.py3-none-any.whl (505 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 505.5/505.5 kB 21.6 MB/s eta 0:00:00
# Collecting tzdata>=2022.7 (from pandas->llama-index-core<0.11.0,>=0.10.12->llama-index)
#   Downloading tzdata-2024.1-py2.py3-none-any.whl (345 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 345.4/345.4 kB 32.3 MB/s eta 0:00:00
# Collecting exceptiongroup>=1.0.2 (from anyio->httpx->llama-index-core<0.11.0,>=0.10.12->llama-index)
#   Downloading exceptiongroup-1.2.0-py3-none-any.whl (16 kB)
# Collecting build>=1.0.3 (from chromadb<0.5.0,>=0.4.22->llama-index-vector-stores-chroma<0.2.0,>=0.1.1->llama-index-cli<0.2.0,>=0.1.2->llama-index)
#   Downloading build-1.0.3-py3-none-any.whl (18 kB)
# Collecting chroma-hnswlib==0.7.3 (from chromadb<0.5.0,>=0.4.22->llama-index-vector-stores-chroma<0.2.0,>=0.1.1->llama-index-cli<0.2.0,>=0.1.2->llama-index)
#   Using cached chroma_hnswlib-0.7.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.4 MB)
# Collecting fastapi>=0.95.2 (from chromadb<0.5.0,>=0.4.22->llama-index-vector-stores-chroma<0.2.0,>=0.1.1->llama-index-cli<0.2.0,>=0.1.2->llama-index)
#   Using cached fastapi-0.109.2-py3-none-any.whl (92 kB)
# Collecting uvicorn[standard]>=0.18.3 (from chromadb<0.5.0,>=0.4.22->llama-index-vector-stores-chroma<0.2.0,>=0.1.1->llama-index-cli<0.2.0,>=0.1.2->llama-index)
#   Using cached uvicorn-0.27.1-py3-none-any.whl (60 kB)
# Collecting posthog>=2.4.0 (from chromadb<0.5.0,>=0.4.22->llama-index-vector-stores-chroma<0.2.0,>=0.1.1->llama-index-cli<0.2.0,>=0.1.2->llama-index)
#   Using cached posthog-3.4.2-py2.py3-none-any.whl (41 kB)
# Collecting pulsar-client>=3.1.0 (from chromadb<0.5.0,>=0.4.22->llama-index-vector-stores-chroma<0.2.0,>=0.1.1->llama-index-cli<0.2.0,>=0.1.2->llama-index)
#   Using cached pulsar_client-3.4.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (5.4 MB)
# Collecting opentelemetry-api>=1.2.0 (from chromadb<0.5.0,>=0.4.22->llama-index-vector-stores-chroma<0.2.0,>=0.1.1->llama-index-cli<0.2.0,>=0.1.2->llama-index)
#   Using cached opentelemetry_api-1.22.0-py3-none-any.whl (57 kB)
# Collecting opentelemetry-exporter-otlp-proto-grpc>=1.2.0 (from chromadb<0.5.0,>=0.4.22->llama-index-vector-stores-chroma<0.2.0,>=0.1.1->llama-index-cli<0.2.0,>=0.1.2->llama-index)
#   Using cached opentelemetry_exporter_otlp_proto_grpc-1.22.0-py3-none-any.whl (18 kB)
# Collecting opentelemetry-instrumentation-fastapi>=0.41b0 (from chromadb<0.5.0,>=0.4.22->llama-index-vector-stores-chroma<0.2.0,>=0.1.1->llama-index-cli<0.2.0,>=0.1.2->llama-index)
#   Using cached opentelemetry_instrumentation_fastapi-0.43b0-py3-none-any.whl (11 kB)
# Collecting opentelemetry-sdk>=1.2.0 (from chromadb<0.5.0,>=0.4.22->llama-index-vector-stores-chroma<0.2.0,>=0.1.1->llama-index-cli<0.2.0,>=0.1.2->llama-index)
#   Using cached opentelemetry_sdk-1.22.0-py3-none-any.whl (105 kB)
# Collecting pypika>=0.48.9 (from chromadb<0.5.0,>=0.4.22->llama-index-vector-stores-chroma<0.2.0,>=0.1.1->llama-index-cli<0.2.0,>=0.1.2->llama-index)
#   Using cached PyPika-0.48.9-py2.py3-none-any.whl
# Collecting overrides>=7.3.1 (from chromadb<0.5.0,>=0.4.22->llama-index-vector-stores-chroma<0.2.0,>=0.1.1->llama-index-cli<0.2.0,>=0.1.2->llama-index)
#   Using cached overrides-7.7.0-py3-none-any.whl (17 kB)
# Collecting importlib-resources (from chromadb<0.5.0,>=0.4.22->llama-index-vector-stores-chroma<0.2.0,>=0.1.1->llama-index-cli<0.2.0,>=0.1.2->llama-index)
#   Downloading importlib_resources-6.1.1-py3-none-any.whl (33 kB)
# Collecting grpcio>=1.58.0 (from chromadb<0.5.0,>=0.4.22->llama-index-vector-stores-chroma<0.2.0,>=0.1.1->llama-index-cli<0.2.0,>=0.1.2->llama-index)
#   Downloading grpcio-1.62.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (5.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 86.7 MB/s eta 0:00:00
# Collecting bcrypt>=4.0.1 (from chromadb<0.5.0,>=0.4.22->llama-index-vector-stores-chroma<0.2.0,>=0.1.1->llama-index-cli<0.2.0,>=0.1.2->llama-index)
#   Using cached bcrypt-4.1.2-cp39-abi3-manylinux_2_28_x86_64.whl (698 kB)
# Collecting typer>=0.9.0 (from chromadb<0.5.0,>=0.4.22->llama-index-vector-stores-chroma<0.2.0,>=0.1.1->llama-index-cli<0.2.0,>=0.1.2->llama-index)
#   Downloading typer-0.9.0-py3-none-any.whl (45 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.9/45.9 kB 881.3 kB/s eta 0:00:00
# Collecting kubernetes>=28.1.0 (from chromadb<0.5.0,>=0.4.22->llama-index-vector-stores-chroma<0.2.0,>=0.1.1->llama-index-cli<0.2.0,>=0.1.2->llama-index)
#   Using cached kubernetes-29.0.0-py2.py3-none-any.whl (1.6 MB)
# Collecting mmh3>=4.0.1 (from chromadb<0.5.0,>=0.4.22->llama-index-vector-stores-chroma<0.2.0,>=0.1.1->llama-index-cli<0.2.0,>=0.1.2->llama-index)
#   Using cached mmh3-4.1.0-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (67 kB)
# Collecting orjson>=3.9.12 (from chromadb<0.5.0,>=0.4.22->llama-index-vector-stores-chroma<0.2.0,>=0.1.1->llama-index-cli<0.2.0,>=0.1.2->llama-index)
#   Using cached orjson-3.9.14-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (138 kB)
# Collecting packaging>=17.0 (from marshmallow<4.0.0,>=3.18.0->dataclasses-json->llama-index-core<0.11.0,>=0.10.12->llama-index)
#   Downloading packaging-23.2-py3-none-any.whl (53 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.0/53.0 kB 7.3 MB/s eta 0:00:00
# Collecting coloredlogs (from onnxruntime<2.0.0,>=1.17.0->llama-index-vector-stores-chroma<0.2.0,>=0.1.1->llama-index-cli<0.2.0,>=0.1.2->llama-index)
#   Using cached coloredlogs-15.0.1-py2.py3-none-any.whl (46 kB)
# Collecting flatbuffers (from onnxruntime<2.0.0,>=1.17.0->llama-index-vector-stores-chroma<0.2.0,>=0.1.1->llama-index-cli<0.2.0,>=0.1.2->llama-index)
#   Downloading flatbuffers-23.5.26-py2.py3-none-any.whl (26 kB)
# Collecting protobuf (from onnxruntime<2.0.0,>=1.17.0->llama-index-vector-stores-chroma<0.2.0,>=0.1.1->llama-index-cli<0.2.0,>=0.1.2->llama-index)
#   Downloading protobuf-4.25.3-cp37-abi3-manylinux2014_x86_64.whl (294 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 294.6/294.6 kB 33.5 MB/s eta 0:00:00
# Collecting sympy (from onnxruntime<2.0.0,>=1.17.0->llama-index-vector-stores-chroma<0.2.0,>=0.1.1->llama-index-cli<0.2.0,>=0.1.2->llama-index)
#   Downloading sympy-1.12-py3-none-any.whl (5.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.7/5.7 MB 86.3 MB/s eta 0:00:00
# Collecting annotated-types>=0.4.0 (from pydantic>=1.10->llamaindex-py-client<0.2.0,>=0.1.13->llama-index-core<0.11.0,>=0.10.12->llama-index)
#   Downloading annotated_types-0.6.0-py3-none-any.whl (12 kB)
# Collecting pydantic-core==2.16.2 (from pydantic>=1.10->llamaindex-py-client<0.2.0,>=0.1.13->llama-index-core<0.11.0,>=0.10.12->llama-index)
#   Downloading pydantic_core-2.16.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 69.9 MB/s eta 0:00:00
# Collecting six>=1.5 (from python-dateutil>=2.8.2->pandas->llama-index-core<0.11.0,>=0.10.12->llama-index)
#   Downloading six-1.16.0-py2.py3-none-any.whl (11 kB)
# Collecting huggingface_hub<1.0,>=0.16.4 (from tokenizers<0.16.0,>=0.15.1->llama-index-vector-stores-chroma<0.2.0,>=0.1.1->llama-index-cli<0.2.0,>=0.1.2->llama-index)
#   Downloading huggingface_hub-0.20.3-py3-none-any.whl (330 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 330.1/330.1 kB 30.5 MB/s eta 0:00:00
# Collecting pyproject_hooks (from build>=1.0.3->chromadb<0.5.0,>=0.4.22->llama-index-vector-stores-chroma<0.2.0,>=0.1.1->llama-index-cli<0.2.0,>=0.1.2->llama-index)
#   Downloading pyproject_hooks-1.0.0-py3-none-any.whl (9.3 kB)
# Collecting tomli>=1.1.0 (from build>=1.0.3->chromadb<0.5.0,>=0.4.22->llama-index-vector-stores-chroma<0.2.0,>=0.1.1->llama-index-cli<0.2.0,>=0.1.2->llama-index)
#   Downloading tomli-2.0.1-py3-none-any.whl (12 kB)
# Collecting starlette<0.37.0,>=0.36.3 (from fastapi>=0.95.2->chromadb<0.5.0,>=0.4.22->llama-index-vector-stores-chroma<0.2.0,>=0.1.1->llama-index-cli<0.2.0,>=0.1.2->llama-index)
#   Using cached starlette-0.36.3-py3-none-any.whl (71 kB)
# Collecting filelock (from huggingface_hub<1.0,>=0.16.4->tokenizers<0.16.0,>=0.15.1->llama-index-vector-stores-chroma<0.2.0,>=0.1.1->llama-index-cli<0.2.0,>=0.1.2->llama-index)
#   Downloading filelock-3.13.1-py3-none-any.whl (11 kB)
# Collecting google-auth>=1.0.1 (from kubernetes>=28.1.0->chromadb<0.5.0,>=0.4.22->llama-index-vector-stores-chroma<0.2.0,>=0.1.1->llama-index-cli<0.2.0,>=0.1.2->llama-index)
#   Downloading google_auth-2.28.1-py2.py3-none-any.whl (186 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 186.9/186.9 kB 23.1 MB/s eta 0:00:00
# Collecting websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 (from kubernetes>=28.1.0->chromadb<0.5.0,>=0.4.22->llama-index-vector-stores-chroma<0.2.0,>=0.1.1->llama-index-cli<0.2.0,>=0.1.2->llama-index)
#   Downloading websocket_client-1.7.0-py3-none-any.whl (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.5/58.5 kB 7.7 MB/s eta 0:00:00
# Collecting requests-oauthlib (from kubernetes>=28.1.0->chromadb<0.5.0,>=0.4.22->llama-index-vector-stores-chroma<0.2.0,>=0.1.1->llama-index-cli<0.2.0,>=0.1.2->llama-index)
#   Downloading requests_oauthlib-1.3.1-py2.py3-none-any.whl (23 kB)
# Collecting oauthlib>=3.2.2 (from kubernetes>=28.1.0->chromadb<0.5.0,>=0.4.22->llama-index-vector-stores-chroma<0.2.0,>=0.1.1->llama-index-cli<0.2.0,>=0.1.2->llama-index)
#   Downloading oauthlib-3.2.2-py3-none-any.whl (151 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 151.7/151.7 kB 15.9 MB/s eta 0:00:00
# Collecting importlib-metadata<7.0,>=6.0 (from opentelemetry-api>=1.2.0->chromadb<0.5.0,>=0.4.22->llama-index-vector-stores-chroma<0.2.0,>=0.1.1->llama-index-cli<0.2.0,>=0.1.2->llama-index)
#   Using cached importlib_metadata-6.11.0-py3-none-any.whl (23 kB)
# Collecting backoff<3.0.0,>=1.10.0 (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb<0.5.0,>=0.4.22->llama-index-vector-stores-chroma<0.2.0,>=0.1.1->llama-index-cli<0.2.0,>=0.1.2->llama-index)
#   Using cached backoff-2.2.1-py3-none-any.whl (15 kB)
# Collecting googleapis-common-protos~=1.52 (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb<0.5.0,>=0.4.22->llama-index-vector-stores-chroma<0.2.0,>=0.1.1->llama-index-cli<0.2.0,>=0.1.2->llama-index)
#   Downloading googleapis_common_protos-1.62.0-py2.py3-none-any.whl (228 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 228.7/228.7 kB 24.3 MB/s eta 0:00:00
# Collecting opentelemetry-exporter-otlp-proto-common==1.22.0 (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb<0.5.0,>=0.4.22->llama-index-vector-stores-chroma<0.2.0,>=0.1.1->llama-index-cli<0.2.0,>=0.1.2->llama-index)
#   Using cached opentelemetry_exporter_otlp_proto_common-1.22.0-py3-none-any.whl (17 kB)
# Collecting opentelemetry-proto==1.22.0 (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb<0.5.0,>=0.4.22->llama-index-vector-stores-chroma<0.2.0,>=0.1.1->llama-index-cli<0.2.0,>=0.1.2->llama-index)
#   Using cached opentelemetry_proto-1.22.0-py3-none-any.whl (50 kB)
# Collecting opentelemetry-instrumentation-asgi==0.43b0 (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb<0.5.0,>=0.4.22->llama-index-vector-stores-chroma<0.2.0,>=0.1.1->llama-index-cli<0.2.0,>=0.1.2->llama-index)
#   Using cached opentelemetry_instrumentation_asgi-0.43b0-py3-none-any.whl (14 kB)
# Collecting opentelemetry-instrumentation==0.43b0 (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb<0.5.0,>=0.4.22->llama-index-vector-stores-chroma<0.2.0,>=0.1.1->llama-index-cli<0.2.0,>=0.1.2->llama-index)
#   Using cached opentelemetry_instrumentation-0.43b0-py3-none-any.whl (28 kB)
# Collecting opentelemetry-semantic-conventions==0.43b0 (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb<0.5.0,>=0.4.22->llama-index-vector-stores-chroma<0.2.0,>=0.1.1->llama-index-cli<0.2.0,>=0.1.2->llama-index)
#   Using cached opentelemetry_semantic_conventions-0.43b0-py3-none-any.whl (36 kB)
# Collecting opentelemetry-util-http==0.43b0 (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb<0.5.0,>=0.4.22->llama-index-vector-stores-chroma<0.2.0,>=0.1.1->llama-index-cli<0.2.0,>=0.1.2->llama-index)
#   Using cached opentelemetry_util_http-0.43b0-py3-none-any.whl (6.9 kB)
# Collecting setuptools>=16.0 (from opentelemetry-instrumentation==0.43b0->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb<0.5.0,>=0.4.22->llama-index-vector-stores-chroma<0.2.0,>=0.1.1->llama-index-cli<0.2.0,>=0.1.2->llama-index)
#   Using cached setuptools-69.1.1-py3-none-any.whl (819 kB)
# Collecting asgiref~=3.0 (from opentelemetry-instrumentation-asgi==0.43b0->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb<0.5.0,>=0.4.22->llama-index-vector-stores-chroma<0.2.0,>=0.1.1->llama-index-cli<0.2.0,>=0.1.2->llama-index)
#   Using cached asgiref-3.7.2-py3-none-any.whl (24 kB)
# Collecting monotonic>=1.5 (from posthog>=2.4.0->chromadb<0.5.0,>=0.4.22->llama-index-vector-stores-chroma<0.2.0,>=0.1.1->llama-index-cli<0.2.0,>=0.1.2->llama-index)
#   Using cached monotonic-1.6-py2.py3-none-any.whl (8.2 kB)
# Collecting httptools>=0.5.0 (from uvicorn[standard]>=0.18.3->chromadb<0.5.0,>=0.4.22->llama-index-vector-stores-chroma<0.2.0,>=0.1.1->llama-index-cli<0.2.0,>=0.1.2->llama-index)
#   Using cached httptools-0.6.1-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (341 kB)
# Collecting python-dotenv>=0.13 (from uvicorn[standard]>=0.18.3->chromadb<0.5.0,>=0.4.22->llama-index-vector-stores-chroma<0.2.0,>=0.1.1->llama-index-cli<0.2.0,>=0.1.2->llama-index)
#   Using cached python_dotenv-1.0.1-py3-none-any.whl (19 kB)
# Collecting uvloop!=0.15.0,!=0.15.1,>=0.14.0 (from uvicorn[standard]>=0.18.3->chromadb<0.5.0,>=0.4.22->llama-index-vector-stores-chroma<0.2.0,>=0.1.1->llama-index-cli<0.2.0,>=0.1.2->llama-index)
#   Using cached uvloop-0.19.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.4 MB)
# Collecting watchfiles>=0.13 (from uvicorn[standard]>=0.18.3->chromadb<0.5.0,>=0.4.22->llama-index-vector-stores-chroma<0.2.0,>=0.1.1->llama-index-cli<0.2.0,>=0.1.2->llama-index)
#   Using cached watchfiles-0.21.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
# Collecting websockets>=10.4 (from uvicorn[standard]>=0.18.3->chromadb<0.5.0,>=0.4.22->llama-index-vector-stores-chroma<0.2.0,>=0.1.1->llama-index-cli<0.2.0,>=0.1.2->llama-index)
#   Using cached websockets-12.0-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (130 kB)
# Collecting humanfriendly>=9.1 (from coloredlogs->onnxruntime<2.0.0,>=1.17.0->llama-index-vector-stores-chroma<0.2.0,>=0.1.1->llama-index-cli<0.2.0,>=0.1.2->llama-index)
#   Using cached humanfriendly-10.0-py2.py3-none-any.whl (86 kB)
# Collecting mpmath>=0.19 (from sympy->onnxruntime<2.0.0,>=1.17.0->llama-index-vector-stores-chroma<0.2.0,>=0.1.1->llama-index-cli<0.2.0,>=0.1.2->llama-index)
#   Downloading mpmath-1.3.0-py3-none-any.whl (536 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 536.2/536.2 kB 53.1 MB/s eta 0:00:00
# Collecting cachetools<6.0,>=2.0.0 (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb<0.5.0,>=0.4.22->llama-index-vector-stores-chroma<0.2.0,>=0.1.1->llama-index-cli<0.2.0,>=0.1.2->llama-index)
#   Downloading cachetools-5.3.2-py3-none-any.whl (9.3 kB)
# Collecting pyasn1-modules>=0.2.1 (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb<0.5.0,>=0.4.22->llama-index-vector-stores-chroma<0.2.0,>=0.1.1->llama-index-cli<0.2.0,>=0.1.2->llama-index)
#   Downloading pyasn1_modules-0.3.0-py2.py3-none-any.whl (181 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 181.3/181.3 kB 25.2 MB/s eta 0:00:00
# Collecting rsa<5,>=3.1.4 (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb<0.5.0,>=0.4.22->llama-index-vector-stores-chroma<0.2.0,>=0.1.1->llama-index-cli<0.2.0,>=0.1.2->llama-index)
#   Downloading rsa-4.9-py3-none-any.whl (34 kB)
# Collecting zipp>=0.5 (from importlib-metadata<7.0,>=6.0->opentelemetry-api>=1.2.0->chromadb<0.5.0,>=0.4.22->llama-index-vector-stores-chroma<0.2.0,>=0.1.1->llama-index-cli<0.2.0,>=0.1.2->llama-index)
#   Downloading zipp-3.17.0-py3-none-any.whl (7.4 kB)
# Collecting pyasn1<0.6.0,>=0.4.6 (from pyasn1-modules>=0.2.1->google-auth>=1.0.1->kubernetes>=28.1.0->chromadb<0.5.0,>=0.4.22->llama-index-vector-stores-chroma<0.2.0,>=0.1.1->llama-index-cli<0.2.0,>=0.1.2->llama-index)
#   Downloading pyasn1-0.5.1-py2.py3-none-any.whl (84 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.9/84.9 kB 12.5 MB/s eta 0:00:00
# Installing collected packages: pytz, pypika, mpmath, monotonic, mmh3, flatbuffers, dirtyjson, zipp, wrapt, websockets, websocket-client, uvloop, urllib3, tzdata, typing-extensions, tqdm, tomli, tenacity, sympy, soupsieve, sniffio, six, setuptools, regex, PyYAML, python-dotenv, pypdf, PyMuPDFb, pyasn1, protobuf, pillow, packaging, overrides, orjson, opentelemetry-util-http, opentelemetry-semantic-conventions, oauthlib, numpy, networkx, nest-asyncio, mypy-extensions, multidict, joblib, importlib-resources, idna, humanfriendly, httptools, h11, grpcio, greenlet, fsspec, frozenlist, filelock, exceptiongroup, distro, click, charset-normalizer, certifi, cachetools, bcrypt, backoff, attrs, async-timeout, annotated-types, yarl, uvicorn, typing-inspect, typer, SQLAlchemy, rsa, requests, python-dateutil, pyproject_hooks, pymupdf, pydantic-core, pyasn1-modules, pulsar-client, opentelemetry-proto, nltk, marshmallow, importlib-metadata, httpcore, googleapis-common-protos, deprecated, coloredlogs, chroma-hnswlib, beautifulsoup4, asgiref, anyio, aiosignal, watchfiles, tiktoken, starlette, requests-oauthlib, pydantic, posthog, pandas, opentelemetry-exporter-otlp-proto-common, opentelemetry-api, onnxruntime, huggingface_hub, httpx, google-auth, dataclasses-json, build, bs4, aiohttp, tokenizers, opentelemetry-sdk, opentelemetry-instrumentation, openai, llamaindex-py-client, kubernetes, fastapi, opentelemetry-instrumentation-asgi, opentelemetry-exporter-otlp-proto-grpc, llama-index-legacy, llama-index-core, opentelemetry-instrumentation-fastapi, llama-parse, llama-index-readers-file, llama-index-llms-openai, llama-index-indices-managed-llama-cloud, llama-index-embeddings-openai, llama-index-readers-llama-parse, llama-index-multi-modal-llms-openai, llama-index-agent-openai, chromadb, llama-index-vector-stores-chroma, llama-index-program-openai, llama-index-question-gen-openai, llama-index-cli, llama-index
#   Attempting uninstall: pytz
#     Found existing installation: pytz 2023.4
#     Uninstalling pytz-2023.4:
#       Successfully uninstalled pytz-2023.4
#   Attempting uninstall: pypika
#     Found existing installation: PyPika 0.48.9
#     Uninstalling PyPika-0.48.9:
#       Successfully uninstalled PyPika-0.48.9
#   Attempting uninstall: mpmath
#     Found existing installation: mpmath 1.3.0
#     Uninstalling mpmath-1.3.0:
#       Successfully uninstalled mpmath-1.3.0
#   Attempting uninstall: monotonic
#     Found existing installation: monotonic 1.6
#     Uninstalling monotonic-1.6:
#       Successfully uninstalled monotonic-1.6
#   Attempting uninstall: mmh3
#     Found existing installation: mmh3 4.1.0
#     Uninstalling mmh3-4.1.0:
#       Successfully uninstalled mmh3-4.1.0
#   Attempting uninstall: flatbuffers
#     Found existing installation: flatbuffers 23.5.26
#     Uninstalling flatbuffers-23.5.26:
#       Successfully uninstalled flatbuffers-23.5.26
#   Attempting uninstall: dirtyjson
#     Found existing installation: dirtyjson 1.0.8
#     Uninstalling dirtyjson-1.0.8:
#       Successfully uninstalled dirtyjson-1.0.8
#   Attempting uninstall: zipp
#     Found existing installation: zipp 3.17.0
#     Uninstalling zipp-3.17.0:
#       Successfully uninstalled zipp-3.17.0
#   Attempting uninstall: wrapt
#     Found existing installation: wrapt 1.14.1
#     Uninstalling wrapt-1.14.1:
#       Successfully uninstalled wrapt-1.14.1
#   Attempting uninstall: websockets
#     Found existing installation: websockets 12.0
#     Uninstalling websockets-12.0:
#       Successfully uninstalled websockets-12.0
#   Attempting uninstall: websocket-client
#     Found existing installation: websocket-client 1.7.0
#     Uninstalling websocket-client-1.7.0:
#       Successfully uninstalled websocket-client-1.7.0
#   Attempting uninstall: uvloop
#     Found existing installation: uvloop 0.19.0
#     Uninstalling uvloop-0.19.0:
#       Successfully uninstalled uvloop-0.19.0
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 2.0.7
#     Uninstalling urllib3-2.0.7:
#       Successfully uninstalled urllib3-2.0.7
#   Attempting uninstall: typing-extensions
#     Found existing installation: typing_extensions 4.9.0
#     Uninstalling typing_extensions-4.9.0:
#       Successfully uninstalled typing_extensions-4.9.0
#   Attempting uninstall: tqdm
#     Found existing installation: tqdm 4.66.2
#     Uninstalling tqdm-4.66.2:
#       Successfully uninstalled tqdm-4.66.2
#   Attempting uninstall: tomli
#     Found existing installation: tomli 2.0.1
#     Uninstalling tomli-2.0.1:
#       Successfully uninstalled tomli-2.0.1
#   Attempting uninstall: tenacity
#     Found existing installation: tenacity 8.2.3
#     Uninstalling tenacity-8.2.3:
#       Successfully uninstalled tenacity-8.2.3
#   Attempting uninstall: sympy
#     Found existing installation: sympy 1.12
#     Uninstalling sympy-1.12:
#       Successfully uninstalled sympy-1.12
#   Attempting uninstall: soupsieve
#     Found existing installation: soupsieve 2.5
#     Uninstalling soupsieve-2.5:
#       Successfully uninstalled soupsieve-2.5
#   Attempting uninstall: sniffio
#     Found existing installation: sniffio 1.3.0
#     Uninstalling sniffio-1.3.0:
#       Successfully uninstalled sniffio-1.3.0
#   Attempting uninstall: six
#     Found existing installation: six 1.16.0
#     Uninstalling six-1.16.0:
#       Successfully uninstalled six-1.16.0
#   Attempting uninstall: setuptools
#     Found existing installation: setuptools 67.7.2
#     Uninstalling setuptools-67.7.2:
#       Successfully uninstalled setuptools-67.7.2
#   Attempting uninstall: regex
#     Found existing installation: regex 2023.12.25
#     Uninstalling regex-2023.12.25:
#       Successfully uninstalled regex-2023.12.25
#   Attempting uninstall: PyYAML
#     Found existing installation: PyYAML 6.0.1
#     Uninstalling PyYAML-6.0.1:
#       Successfully uninstalled PyYAML-6.0.1
#   Attempting uninstall: python-dotenv
#     Found existing installation: python-dotenv 1.0.1
#     Uninstalling python-dotenv-1.0.1:
#       Successfully uninstalled python-dotenv-1.0.1
#   Attempting uninstall: pypdf
#     Found existing installation: pypdf 4.0.2
#     Uninstalling pypdf-4.0.2:
#       Successfully uninstalled pypdf-4.0.2
#   Attempting uninstall: PyMuPDFb
#     Found existing installation: PyMuPDFb 1.23.22
#     Uninstalling PyMuPDFb-1.23.22:
#       Successfully uninstalled PyMuPDFb-1.23.22
#   Attempting uninstall: pyasn1
#     Found existing installation: pyasn1 0.5.1
#     Uninstalling pyasn1-0.5.1:
#       Successfully uninstalled pyasn1-0.5.1
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 3.20.3
#     Uninstalling protobuf-3.20.3:
#       Successfully uninstalled protobuf-3.20.3
#   Attempting uninstall: pillow
#     Found existing installation: Pillow 9.4.0
#     Uninstalling Pillow-9.4.0:
#       Successfully uninstalled Pillow-9.4.0
#   Attempting uninstall: packaging
#     Found existing installation: packaging 23.2
#     Uninstalling packaging-23.2:
#       Successfully uninstalled packaging-23.2
#   Attempting uninstall: overrides
#     Found existing installation: overrides 7.7.0
#     Uninstalling overrides-7.7.0:
#       Successfully uninstalled overrides-7.7.0
#   Attempting uninstall: orjson
#     Found existing installation: orjson 3.9.14
#     Uninstalling orjson-3.9.14:
#       Successfully uninstalled orjson-3.9.14
#   Attempting uninstall: opentelemetry-util-http
#     Found existing installation: opentelemetry-util-http 0.43b0
#     Uninstalling opentelemetry-util-http-0.43b0:
#       Successfully uninstalled opentelemetry-util-http-0.43b0
#   Attempting uninstall: opentelemetry-semantic-conventions
#     Found existing installation: opentelemetry-semantic-conventions 0.43b0
#     Uninstalling opentelemetry-semantic-conventions-0.43b0:
#       Successfully uninstalled opentelemetry-semantic-conventions-0.43b0
#   Attempting uninstall: oauthlib
#     Found existing installation: oauthlib 3.2.2
#     Uninstalling oauthlib-3.2.2:
#       Successfully uninstalled oauthlib-3.2.2
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.25.2
#     Uninstalling numpy-1.25.2:
#       Successfully uninstalled numpy-1.25.2
#   Attempting uninstall: networkx
#     Found existing installation: networkx 3.2.1
#     Uninstalling networkx-3.2.1:
#       Successfully uninstalled networkx-3.2.1
#   Attempting uninstall: nest-asyncio
#     Found existing installation: nest-asyncio 1.6.0
#     Uninstalling nest-asyncio-1.6.0:
#       Successfully uninstalled nest-asyncio-1.6.0
#   Attempting uninstall: mypy-extensions
#     Found existing installation: mypy-extensions 1.0.0
#     Uninstalling mypy-extensions-1.0.0:
#       Successfully uninstalled mypy-extensions-1.0.0
#   Attempting uninstall: multidict
#     Found existing installation: multidict 6.0.5
#     Uninstalling multidict-6.0.5:
#       Successfully uninstalled multidict-6.0.5
#   Attempting uninstall: joblib
#     Found existing installation: joblib 1.3.2
#     Uninstalling joblib-1.3.2:
#       Successfully uninstalled joblib-1.3.2
#   Attempting uninstall: importlib-resources
#     Found existing installation: importlib-resources 6.1.1
#     Uninstalling importlib-resources-6.1.1:
#       Successfully uninstalled importlib-resources-6.1.1
#   Attempting uninstall: idna
#     Found existing installation: idna 3.6
#     Uninstalling idna-3.6:
#       Successfully uninstalled idna-3.6
#   Attempting uninstall: humanfriendly
#     Found existing installation: humanfriendly 10.0
#     Uninstalling humanfriendly-10.0:
#       Successfully uninstalled humanfriendly-10.0
#   Attempting uninstall: httptools
#     Found existing installation: httptools 0.6.1
#     Uninstalling httptools-0.6.1:
#       Successfully uninstalled httptools-0.6.1
#   Attempting uninstall: h11
#     Found existing installation: h11 0.14.0
#     Uninstalling h11-0.14.0:
#       Successfully uninstalled h11-0.14.0
#   Attempting uninstall: grpcio
#     Found existing installation: grpcio 1.60.1
#     Uninstalling grpcio-1.60.1:
#       Successfully uninstalled grpcio-1.60.1
#   Attempting uninstall: greenlet
#     Found existing installation: greenlet 3.0.3
#     Uninstalling greenlet-3.0.3:
#       Successfully uninstalled greenlet-3.0.3
#   Attempting uninstall: fsspec
#     Found existing installation: fsspec 2023.6.0
#     Uninstalling fsspec-2023.6.0:
#       Successfully uninstalled fsspec-2023.6.0
#   Attempting uninstall: frozenlist
#     Found existing installation: frozenlist 1.4.1
#     Uninstalling frozenlist-1.4.1:
#       Successfully uninstalled frozenlist-1.4.1
#   Attempting uninstall: filelock
#     Found existing installation: filelock 3.13.1
#     Uninstalling filelock-3.13.1:
#       Successfully uninstalled filelock-3.13.1
#   Attempting uninstall: exceptiongroup
#     Found existing installation: exceptiongroup 1.2.0
#     Uninstalling exceptiongroup-1.2.0:
#       Successfully uninstalled exceptiongroup-1.2.0
#   Attempting uninstall: distro
#     Found existing installation: distro 1.7.0
#     Uninstalling distro-1.7.0:
#       Successfully uninstalled distro-1.7.0
#   Attempting uninstall: click
#     Found existing installation: click 8.1.7
#     Uninstalling click-8.1.7:
#       Successfully uninstalled click-8.1.7
#   Attempting uninstall: charset-normalizer
#     Found existing installation: charset-normalizer 3.3.2
#     Uninstalling charset-normalizer-3.3.2:
#       Successfully uninstalled charset-normalizer-3.3.2
#   Attempting uninstall: certifi
#     Found existing installation: certifi 2024.2.2
#     Uninstalling certifi-2024.2.2:
#       Successfully uninstalled certifi-2024.2.2
#   Attempting uninstall: cachetools
#     Found existing installation: cachetools 5.3.2
#     Uninstalling cachetools-5.3.2:
#       Successfully uninstalled cachetools-5.3.2
#   Attempting uninstall: bcrypt
#     Found existing installation: bcrypt 4.1.2
#     Uninstalling bcrypt-4.1.2:
#       Successfully uninstalled bcrypt-4.1.2
#   Attempting uninstall: backoff
#     Found existing installation: backoff 2.2.1
#     Uninstalling backoff-2.2.1:
#       Successfully uninstalled backoff-2.2.1
#   Attempting uninstall: attrs
#     Found existing installation: attrs 23.2.0
#     Uninstalling attrs-23.2.0:
#       Successfully uninstalled attrs-23.2.0
#   Attempting uninstall: async-timeout
#     Found existing installation: async-timeout 4.0.3
#     Uninstalling async-timeout-4.0.3:
#       Successfully uninstalled async-timeout-4.0.3
#   Attempting uninstall: annotated-types
#     Found existing installation: annotated-types 0.6.0
#     Uninstalling annotated-types-0.6.0:
#       Successfully uninstalled annotated-types-0.6.0
#   Attempting uninstall: yarl
#     Found existing installation: yarl 1.9.4
#     Uninstalling yarl-1.9.4:
#       Successfully uninstalled yarl-1.9.4
#   Attempting uninstall: uvicorn
#     Found existing installation: uvicorn 0.27.1
#     Uninstalling uvicorn-0.27.1:
#       Successfully uninstalled uvicorn-0.27.1
#   Attempting uninstall: typing-inspect
#     Found existing installation: typing-inspect 0.9.0
#     Uninstalling typing-inspect-0.9.0:
#       Successfully uninstalled typing-inspect-0.9.0
#   Attempting uninstall: typer
#     Found existing installation: typer 0.9.0
#     Uninstalling typer-0.9.0:
#       Successfully uninstalled typer-0.9.0
#   Attempting uninstall: SQLAlchemy
#     Found existing installation: SQLAlchemy 2.0.27
#     Uninstalling SQLAlchemy-2.0.27:
#       Successfully uninstalled SQLAlchemy-2.0.27
#   Attempting uninstall: rsa
#     Found existing installation: rsa 4.9
#     Uninstalling rsa-4.9:
#       Successfully uninstalled rsa-4.9
#   Attempting uninstall: requests
#     Found existing installation: requests 2.31.0
#     Uninstalling requests-2.31.0:
#       Successfully uninstalled requests-2.31.0
#   Attempting uninstall: python-dateutil
#     Found existing installation: python-dateutil 2.8.2
#     Uninstalling python-dateutil-2.8.2:
#       Successfully uninstalled python-dateutil-2.8.2
#   Attempting uninstall: pyproject_hooks
#     Found existing installation: pyproject_hooks 1.0.0
#     Uninstalling pyproject_hooks-1.0.0:
#       Successfully uninstalled pyproject_hooks-1.0.0
#   Attempting uninstall: pymupdf
#     Found existing installation: PyMuPDF 1.23.25
#     Uninstalling PyMuPDF-1.23.25:
#       Successfully uninstalled PyMuPDF-1.23.25
#   Attempting uninstall: pydantic-core
#     Found existing installation: pydantic_core 2.16.2
#     Uninstalling pydantic_core-2.16.2:
#       Successfully uninstalled pydantic_core-2.16.2
#   Attempting uninstall: pyasn1-modules
#     Found existing installation: pyasn1-modules 0.3.0
#     Uninstalling pyasn1-modules-0.3.0:
#       Successfully uninstalled pyasn1-modules-0.3.0
#   Attempting uninstall: pulsar-client
#     Found existing installation: pulsar-client 3.4.0
#     Uninstalling pulsar-client-3.4.0:
#       Successfully uninstalled pulsar-client-3.4.0
#   Attempting uninstall: opentelemetry-proto
#     Found existing installation: opentelemetry-proto 1.22.0
#     Uninstalling opentelemetry-proto-1.22.0:
#       Successfully uninstalled opentelemetry-proto-1.22.0
#   Attempting uninstall: nltk
#     Found existing installation: nltk 3.8.1
#     Uninstalling nltk-3.8.1:
#       Successfully uninstalled nltk-3.8.1
#   Attempting uninstall: marshmallow
#     Found existing installation: marshmallow 3.20.2
#     Uninstalling marshmallow-3.20.2:
#       Successfully uninstalled marshmallow-3.20.2
#   Attempting uninstall: importlib-metadata
#     Found existing installation: importlib-metadata 6.11.0
#     Uninstalling importlib-metadata-6.11.0:
#       Successfully uninstalled importlib-metadata-6.11.0
#   Attempting uninstall: httpcore
#     Found existing installation: httpcore 1.0.4
#     Uninstalling httpcore-1.0.4:
#       Successfully uninstalled httpcore-1.0.4
#   Attempting uninstall: googleapis-common-protos
#     Found existing installation: googleapis-common-protos 1.62.0
#     Uninstalling googleapis-common-protos-1.62.0:
#       Successfully uninstalled googleapis-common-protos-1.62.0
#   Attempting uninstall: deprecated
#     Found existing installation: Deprecated 1.2.14
#     Uninstalling Deprecated-1.2.14:
#       Successfully uninstalled Deprecated-1.2.14
#   Attempting uninstall: coloredlogs
#     Found existing installation: coloredlogs 15.0.1
#     Uninstalling coloredlogs-15.0.1:
#       Successfully uninstalled coloredlogs-15.0.1
#   Attempting uninstall: chroma-hnswlib
#     Found existing installation: chroma-hnswlib 0.7.3
#     Uninstalling chroma-hnswlib-0.7.3:
#       Successfully uninstalled chroma-hnswlib-0.7.3
#   Attempting uninstall: beautifulsoup4
#     Found existing installation: beautifulsoup4 4.12.3
#     Uninstalling beautifulsoup4-4.12.3:
#       Successfully uninstalled beautifulsoup4-4.12.3
#   Attempting uninstall: asgiref
#     Found existing installation: asgiref 3.7.2
#     Uninstalling asgiref-3.7.2:
#       Successfully uninstalled asgiref-3.7.2
#   Attempting uninstall: anyio
#     Found existing installation: anyio 3.7.1
#     Uninstalling anyio-3.7.1:
#       Successfully uninstalled anyio-3.7.1
#   Attempting uninstall: aiosignal
#     Found existing installation: aiosignal 1.3.1
#     Uninstalling aiosignal-1.3.1:
#       Successfully uninstalled aiosignal-1.3.1
#   Attempting uninstall: watchfiles
#     Found existing installation: watchfiles 0.21.0
#     Uninstalling watchfiles-0.21.0:
#       Successfully uninstalled watchfiles-0.21.0
#   Attempting uninstall: tiktoken
#     Found existing installation: tiktoken 0.4.0
#     Uninstalling tiktoken-0.4.0:
#       Successfully uninstalled tiktoken-0.4.0
#   Attempting uninstall: starlette
#     Found existing installation: starlette 0.36.3
#     Uninstalling starlette-0.36.3:
#       Successfully uninstalled starlette-0.36.3
#   Attempting uninstall: requests-oauthlib
#     Found existing installation: requests-oauthlib 1.3.1
#     Uninstalling requests-oauthlib-1.3.1:
#       Successfully uninstalled requests-oauthlib-1.3.1
#   Attempting uninstall: pydantic
#     Found existing installation: pydantic 1.10.14
#     Uninstalling pydantic-1.10.14:
#       Successfully uninstalled pydantic-1.10.14
#   Attempting uninstall: posthog
#     Found existing installation: posthog 3.4.2
#     Uninstalling posthog-3.4.2:
#       Successfully uninstalled posthog-3.4.2
#   Attempting uninstall: pandas
#     Found existing installation: pandas 1.5.3
#     Uninstalling pandas-1.5.3:
#       Successfully uninstalled pandas-1.5.3
#   Attempting uninstall: opentelemetry-exporter-otlp-proto-common
#     Found existing installation: opentelemetry-exporter-otlp-proto-common 1.22.0
#     Uninstalling opentelemetry-exporter-otlp-proto-common-1.22.0:
#       Successfully uninstalled opentelemetry-exporter-otlp-proto-common-1.22.0
#   Attempting uninstall: opentelemetry-api
#     Found existing installation: opentelemetry-api 1.22.0
#     Uninstalling opentelemetry-api-1.22.0:
#       Successfully uninstalled opentelemetry-api-1.22.0
#   Attempting uninstall: onnxruntime
#     Found existing installation: onnxruntime 1.17.0
#     Uninstalling onnxruntime-1.17.0:
#       Successfully uninstalled onnxruntime-1.17.0
#   Attempting uninstall: huggingface_hub
#     Found existing installation: huggingface-hub 0.20.3
#     Uninstalling huggingface-hub-0.20.3:
#       Successfully uninstalled huggingface-hub-0.20.3
#   Attempting uninstall: httpx
#     Found existing installation: httpx 0.27.0
#     Uninstalling httpx-0.27.0:
#       Successfully uninstalled httpx-0.27.0
#   Attempting uninstall: google-auth
#     Found existing installation: google-auth 2.27.0
#     Uninstalling google-auth-2.27.0:
#       Successfully uninstalled google-auth-2.27.0
#   Attempting uninstall: dataclasses-json
#     Found existing installation: dataclasses-json 0.6.4
#     Uninstalling dataclasses-json-0.6.4:
#       Successfully uninstalled dataclasses-json-0.6.4
#   Attempting uninstall: build
#     Found existing installation: build 1.0.3
#     Uninstalling build-1.0.3:
#       Successfully uninstalled build-1.0.3
#   Attempting uninstall: bs4
#     Found existing installation: bs4 0.0.2
#     Uninstalling bs4-0.0.2:
#       Successfully uninstalled bs4-0.0.2
#   Attempting uninstall: aiohttp
#     Found existing installation: aiohttp 3.9.3
#     Uninstalling aiohttp-3.9.3:
#       Successfully uninstalled aiohttp-3.9.3
#   Attempting uninstall: tokenizers
#     Found existing installation: tokenizers 0.15.2
#     Uninstalling tokenizers-0.15.2:
#       Successfully uninstalled tokenizers-0.15.2
#   Attempting uninstall: opentelemetry-sdk
#     Found existing installation: opentelemetry-sdk 1.22.0
#     Uninstalling opentelemetry-sdk-1.22.0:
#       Successfully uninstalled opentelemetry-sdk-1.22.0
#   Attempting uninstall: opentelemetry-instrumentation
#     Found existing installation: opentelemetry-instrumentation 0.43b0
#     Uninstalling opentelemetry-instrumentation-0.43b0:
#       Successfully uninstalled opentelemetry-instrumentation-0.43b0
#   Attempting uninstall: openai
#     Found existing installation: openai 1.12.0
#     Uninstalling openai-1.12.0:
#       Successfully uninstalled openai-1.12.0
#   Attempting uninstall: llamaindex-py-client
#     Found existing installation: llamaindex-py-client 0.1.13
#     Uninstalling llamaindex-py-client-0.1.13:
#       Successfully uninstalled llamaindex-py-client-0.1.13
#   Attempting uninstall: kubernetes
#     Found existing installation: kubernetes 29.0.0
#     Uninstalling kubernetes-29.0.0:
#       Successfully uninstalled kubernetes-29.0.0
#   Attempting uninstall: fastapi
#     Found existing installation: fastapi 0.109.2
#     Uninstalling fastapi-0.109.2:
#       Successfully uninstalled fastapi-0.109.2
#   Attempting uninstall: opentelemetry-instrumentation-asgi
#     Found existing installation: opentelemetry-instrumentation-asgi 0.43b0
#     Uninstalling opentelemetry-instrumentation-asgi-0.43b0:
#       Successfully uninstalled opentelemetry-instrumentation-asgi-0.43b0
#   Attempting uninstall: opentelemetry-exporter-otlp-proto-grpc
#     Found existing installation: opentelemetry-exporter-otlp-proto-grpc 1.22.0
#     Uninstalling opentelemetry-exporter-otlp-proto-grpc-1.22.0:
#       Successfully uninstalled opentelemetry-exporter-otlp-proto-grpc-1.22.0
#   Attempting uninstall: llama-index-legacy
#     Found existing installation: llama-index-legacy 0.9.48
#     Uninstalling llama-index-legacy-0.9.48:
#       Successfully uninstalled llama-index-legacy-0.9.48
#   Attempting uninstall: llama-index-core
#     Found existing installation: llama-index-core 0.10.12
#     Uninstalling llama-index-core-0.10.12:
#       Successfully uninstalled llama-index-core-0.10.12
#   Attempting uninstall: opentelemetry-instrumentation-fastapi
#     Found existing installation: opentelemetry-instrumentation-fastapi 0.43b0
#     Uninstalling opentelemetry-instrumentation-fastapi-0.43b0:
#       Successfully uninstalled opentelemetry-instrumentation-fastapi-0.43b0
#   Attempting uninstall: llama-parse
#     Found existing installation: llama-parse 0.3.4
#     Uninstalling llama-parse-0.3.4:
#       Successfully uninstalled llama-parse-0.3.4
#   Attempting uninstall: llama-index-readers-file
#     Found existing installation: llama-index-readers-file 0.1.5
#     Uninstalling llama-index-readers-file-0.1.5:
#       Successfully uninstalled llama-index-readers-file-0.1.5
#   Attempting uninstall: llama-index-llms-openai
#     Found existing installation: llama-index-llms-openai 0.1.6
#     Uninstalling llama-index-llms-openai-0.1.6:
#       Successfully uninstalled llama-index-llms-openai-0.1.6
#   Attempting uninstall: llama-index-indices-managed-llama-cloud
#     Found existing installation: llama-index-indices-managed-llama-cloud 0.1.3
#     Uninstalling llama-index-indices-managed-llama-cloud-0.1.3:
#       Successfully uninstalled llama-index-indices-managed-llama-cloud-0.1.3
#   Attempting uninstall: llama-index-embeddings-openai
#     Found existing installation: llama-index-embeddings-openai 0.1.6
#     Uninstalling llama-index-embeddings-openai-0.1.6:
#       Successfully uninstalled llama-index-embeddings-openai-0.1.6
#   Attempting uninstall: llama-index-readers-llama-parse
#     Found existing installation: llama-index-readers-llama-parse 0.1.3
#     Uninstalling llama-index-readers-llama-parse-0.1.3:
#       Successfully uninstalled llama-index-readers-llama-parse-0.1.3
#   Attempting uninstall: llama-index-multi-modal-llms-openai
#     Found existing installation: llama-index-multi-modal-llms-openai 0.1.4
#     Uninstalling llama-index-multi-modal-llms-openai-0.1.4:
#       Successfully uninstalled llama-index-multi-modal-llms-openai-0.1.4
#   Attempting uninstall: llama-index-agent-openai
#     Found existing installation: llama-index-agent-openai 0.1.5
#     Uninstalling llama-index-agent-openai-0.1.5:
#       Successfully uninstalled llama-index-agent-openai-0.1.5
#   Attempting uninstall: chromadb
#     Found existing installation: chromadb 0.4.23
#     Uninstalling chromadb-0.4.23:
#       Successfully uninstalled chromadb-0.4.23
#   Attempting uninstall: llama-index-vector-stores-chroma
#     Found existing installation: llama-index-vector-stores-chroma 0.1.4
#     Uninstalling llama-index-vector-stores-chroma-0.1.4:
#       Successfully uninstalled llama-index-vector-stores-chroma-0.1.4
#   Attempting uninstall: llama-index-program-openai
#     Found existing installation: llama-index-program-openai 0.1.4
#     Uninstalling llama-index-program-openai-0.1.4:
#       Successfully uninstalled llama-index-program-openai-0.1.4
#   Attempting uninstall: llama-index-question-gen-openai
#     Found existing installation: llama-index-question-gen-openai 0.1.3
#     Uninstalling llama-index-question-gen-openai-0.1.3:
#       Successfully uninstalled llama-index-question-gen-openai-0.1.3
#   Attempting uninstall: llama-index-cli
#     Found existing installation: llama-index-cli 0.1.5
#     Uninstalling llama-index-cli-0.1.5:
#       Successfully uninstalled llama-index-cli-0.1.5
#   Attempting uninstall: llama-index
#     Found existing installation: llama-index 0.10.12
#     Uninstalling llama-index-0.10.12:
#       Successfully uninstalled llama-index-0.10.12
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# ipython 7.34.0 requires jedi>=0.16, which is not installed.
# bigframes 0.21.0 requires pandas<2.1.4,>=1.5.0, but you have pandas 2.2.0 which is incompatible.
# gcsfs 2023.6.0 requires fsspec==2023.6.0, but you have fsspec 2024.2.0 which is incompatible.
# google-colab 1.0.0 requires google-auth==2.27.0, but you have google-auth 2.28.1 which is incompatible.
# google-colab 1.0.0 requires pandas==1.5.3, but you have pandas 2.2.0 which is incompatible.
# gradientai 1.7.0 requires pydantic<2.0.0,>=1.10.5, but you have pydantic 2.6.1 which is incompatible.
# imageio 2.31.6 requires pillow<10.1.0,>=8.3.2, but you have pillow 10.2.0 which is incompatible.
# jupyter-server 1.24.0 requires anyio<4,>=3.1.0, but you have anyio 4.3.0 which is incompatible.
# tensorflow 2.15.0 requires wrapt<1.15,>=1.11.0, but you have wrapt 1.16.0 which is incompatible.
# tensorflow-metadata 1.14.0 requires protobuf<4.21,>=3.20.3, but you have protobuf 4.25.3 which is incompatible.
# Successfully installed PyMuPDFb-1.23.22 PyYAML-6.0.1 SQLAlchemy-2.0.27 aiohttp-3.9.3 aiosignal-1.3.1 annotated-types-0.6.0 anyio-4.3.0 asgiref-3.7.2 async-timeout-4.0.3 attrs-23.2.0 backoff-2.2.1 bcrypt-4.1.2 beautifulsoup4-4.12.3 bs4-0.0.2 build-1.0.3 cachetools-5.3.2 certifi-2024.2.2 charset-normalizer-3.3.2 chroma-hnswlib-0.7.3 chromadb-0.4.23 click-8.1.7 coloredlogs-15.0.1 dataclasses-json-0.6.4 deprecated-1.2.14 dirtyjson-1.0.8 distro-1.9.0 exceptiongroup-1.2.0 fastapi-0.109.2 filelock-3.13.1 flatbuffers-23.5.26 frozenlist-1.4.1 fsspec-2024.2.0 google-auth-2.28.1 googleapis-common-protos-1.62.0 greenlet-3.0.3 grpcio-1.62.0 h11-0.14.0 httpcore-1.0.4 httptools-0.6.1 httpx-0.27.0 huggingface_hub-0.20.3 humanfriendly-10.0 idna-3.6 importlib-metadata-6.11.0 importlib-resources-6.1.1 joblib-1.3.2 kubernetes-29.0.0 llama-index-0.10.12 llama-index-agent-openai-0.1.5 llama-index-cli-0.1.5 llama-index-core-0.10.12 llama-index-embeddings-openai-0.1.6 llama-index-indices-managed-llama-cloud-0.1.3 llama-index-legacy-0.9.48 llama-index-llms-openai-0.1.6 llama-index-multi-modal-llms-openai-0.1.4 llama-index-program-openai-0.1.4 llama-index-question-gen-openai-0.1.3 llama-index-readers-file-0.1.5 llama-index-readers-llama-parse-0.1.3 llama-index-vector-stores-chroma-0.1.4 llama-parse-0.3.4 llamaindex-py-client-0.1.13 marshmallow-3.20.2 mmh3-4.1.0 monotonic-1.6 mpmath-1.3.0 multidict-6.0.5 mypy-extensions-1.0.0 nest-asyncio-1.6.0 networkx-3.2.1 nltk-3.8.1 numpy-1.26.4 oauthlib-3.2.2 onnxruntime-1.17.0 openai-1.12.0 opentelemetry-api-1.22.0 opentelemetry-exporter-otlp-proto-common-1.22.0 opentelemetry-exporter-otlp-proto-grpc-1.22.0 opentelemetry-instrumentation-0.43b0 opentelemetry-instrumentation-asgi-0.43b0 opentelemetry-instrumentation-fastapi-0.43b0 opentelemetry-proto-1.22.0 opentelemetry-sdk-1.22.0 opentelemetry-semantic-conventions-0.43b0 opentelemetry-util-http-0.43b0 orjson-3.9.14 overrides-7.7.0 packaging-23.2 pandas-2.2.0 pillow-10.2.0 posthog-3.4.2 protobuf-4.25.3 pulsar-client-3.4.0 pyasn1-0.5.1 pyasn1-modules-0.3.0 pydantic-2.6.1 pydantic-core-2.16.2 pymupdf-1.23.25 pypdf-4.0.2 pypika-0.48.9 pyproject_hooks-1.0.0 python-dateutil-2.8.2 python-dotenv-1.0.1 pytz-2024.1 regex-2023.12.25 requests-2.31.0 requests-oauthlib-1.3.1 rsa-4.9 setuptools-69.1.1 six-1.16.0 sniffio-1.3.0 soupsieve-2.5 starlette-0.36.3 sympy-1.12 tenacity-8.2.3 tiktoken-0.6.0 tokenizers-0.15.2 tomli-2.0.1 tqdm-4.66.2 typer-0.9.0 typing-extensions-4.9.0 typing-inspect-0.9.0 tzdata-2024.1 urllib3-2.2.1 uvicorn-0.27.1 uvloop-0.19.0 watchfiles-0.21.0 websocket-client-1.7.0 websockets-12.0 wrapt-1.16.0 yarl-1.9.4 zipp-3.17.0

# %%
# %pip install llama-index-llms-gradient
# %pip install llama-index-embeddings-gradient
# Out:
# Collecting llama-index-llms-gradient
#   Downloading llama_index_llms_gradient-0.1.2-py3-none-any.whl (2.9 kB)
# Requirement already satisfied: gradientai<2.0.0,>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from llama-index-llms-gradient) (1.7.0)
# Requirement already satisfied: llama-index-core<0.11.0,>=0.10.1 in /usr/local/lib/python3.10/dist-packages (from llama-index-llms-gradient) (0.10.12)
# Requirement already satisfied: aenum>=3.1.11 in /usr/local/lib/python3.10/dist-packages (from gradientai<2.0.0,>=1.6.0->llama-index-llms-gradient) (3.1.15)
# Requirement already satisfied: pydantic<2.0.0,>=1.10.5 in /usr/local/lib/python3.10/dist-packages (from gradientai<2.0.0,>=1.6.0->llama-index-llms-gradient) (1.10.14)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from gradientai<2.0.0,>=1.6.0->llama-index-llms-gradient) (2.8.2)
# Requirement already satisfied: urllib3>=1.25.3 in /usr/local/lib/python3.10/dist-packages (from gradientai<2.0.0,>=1.6.0->llama-index-llms-gradient) (2.2.1)
# Requirement already satisfied: PyYAML>=6.0.1 in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-llms-gradient) (6.0.1)
# Requirement already satisfied: SQLAlchemy[asyncio]>=1.4.49 in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-llms-gradient) (2.0.27)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.6 in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-llms-gradient) (3.9.3)
# Requirement already satisfied: dataclasses-json in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-llms-gradient) (0.6.4)
# Requirement already satisfied: deprecated>=1.2.9.3 in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-llms-gradient) (1.2.14)
# Requirement already satisfied: dirtyjson<2.0.0,>=1.0.8 in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-llms-gradient) (1.0.8)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-llms-gradient) (2024.2.0)
# Requirement already satisfied: httpx in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-llms-gradient) (0.27.0)
# Requirement already satisfied: llamaindex-py-client<0.2.0,>=0.1.13 in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-llms-gradient) (0.1.13)
# Requirement already satisfied: nest-asyncio<2.0.0,>=1.5.8 in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-llms-gradient) (1.6.0)
# Requirement already satisfied: networkx>=3.0 in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-llms-gradient) (3.2.1)
# Requirement already satisfied: nltk<4.0.0,>=3.8.1 in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-llms-gradient) (3.8.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-llms-gradient) (1.26.4)
# Requirement already satisfied: openai>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-llms-gradient) (1.12.0)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-llms-gradient) (2.2.0)
# Requirement already satisfied: pillow>=9.0.0 in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-llms-gradient) (10.2.0)
# Requirement already satisfied: requests>=2.31.0 in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-llms-gradient) (2.31.0)
# Requirement already satisfied: tenacity<9.0.0,>=8.2.0 in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-llms-gradient) (8.2.3)
# Requirement already satisfied: tiktoken>=0.3.3 in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-llms-gradient) (0.4.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.66.1 in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-llms-gradient) (4.66.2)
# Requirement already satisfied: typing-extensions>=4.5.0 in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-llms-gradient) (4.9.0)
# Requirement already satisfied: typing-inspect>=0.8.0 in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-llms-gradient) (0.9.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.11.0,>=0.10.1->llama-index-llms-gradient) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.11.0,>=0.10.1->llama-index-llms-gradient) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.11.0,>=0.10.1->llama-index-llms-gradient) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.11.0,>=0.10.1->llama-index-llms-gradient) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.11.0,>=0.10.1->llama-index-llms-gradient) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.11.0,>=0.10.1->llama-index-llms-gradient) (4.0.3)
# Requirement already satisfied: wrapt<2,>=1.10 in /usr/local/lib/python3.10/dist-packages (from deprecated>=1.2.9.3->llama-index-core<0.11.0,>=0.10.1->llama-index-llms-gradient) (1.16.0)
# Requirement already satisfied: anyio in /usr/local/lib/python3.10/dist-packages (from httpx->llama-index-core<0.11.0,>=0.10.1->llama-index-llms-gradient) (4.3.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from httpx->llama-index-core<0.11.0,>=0.10.1->llama-index-llms-gradient) (2024.2.2)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.10/dist-packages (from httpx->llama-index-core<0.11.0,>=0.10.1->llama-index-llms-gradient) (1.0.4)
# Requirement already satisfied: idna in /usr/local/lib/python3.10/dist-packages (from httpx->llama-index-core<0.11.0,>=0.10.1->llama-index-llms-gradient) (3.6)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from httpx->llama-index-core<0.11.0,>=0.10.1->llama-index-llms-gradient) (1.3.0)
# Requirement already satisfied: h11<0.15,>=0.13 in /usr/local/lib/python3.10/dist-packages (from httpcore==1.*->httpx->llama-index-core<0.11.0,>=0.10.1->llama-index-llms-gradient) (0.14.0)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk<4.0.0,>=3.8.1->llama-index-core<0.11.0,>=0.10.1->llama-index-llms-gradient) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk<4.0.0,>=3.8.1->llama-index-core<0.11.0,>=0.10.1->llama-index-llms-gradient) (1.3.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.10/dist-packages (from nltk<4.0.0,>=3.8.1->llama-index-core<0.11.0,>=0.10.1->llama-index-llms-gradient) (2023.12.25)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.10/dist-packages (from openai>=1.1.0->llama-index-core<0.11.0,>=0.10.1->llama-index-llms-gradient) (1.9.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->gradientai<2.0.0,>=1.6.0->llama-index-llms-gradient) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.31.0->llama-index-core<0.11.0,>=0.10.1->llama-index-llms-gradient) (3.3.2)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.10/dist-packages (from SQLAlchemy[asyncio]>=1.4.49->llama-index-core<0.11.0,>=0.10.1->llama-index-llms-gradient) (3.0.3)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from typing-inspect>=0.8.0->llama-index-core<0.11.0,>=0.10.1->llama-index-llms-gradient) (1.0.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /usr/local/lib/python3.10/dist-packages (from dataclasses-json->llama-index-core<0.11.0,>=0.10.1->llama-index-llms-gradient) (3.20.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->llama-index-core<0.11.0,>=0.10.1->llama-index-llms-gradient) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas->llama-index-core<0.11.0,>=0.10.1->llama-index-llms-gradient) (2024.1)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /usr/local/lib/python3.10/dist-packages (from anyio->httpx->llama-index-core<0.11.0,>=0.10.1->llama-index-llms-gradient) (1.2.0)
# Requirement already satisfied: packaging>=17.0 in /usr/local/lib/python3.10/dist-packages (from marshmallow<4.0.0,>=3.18.0->dataclasses-json->llama-index-core<0.11.0,>=0.10.1->llama-index-llms-gradient) (23.2)
# Installing collected packages: llama-index-llms-gradient
# Successfully installed llama-index-llms-gradient-0.1.2
# Collecting llama-index-embeddings-gradient
#   Downloading llama_index_embeddings_gradient-0.1.2-py3-none-any.whl (3.3 kB)
# Requirement already satisfied: gradientai<2.0.0,>=1.5.0 in /usr/local/lib/python3.10/dist-packages (from llama-index-embeddings-gradient) (1.7.0)
# Requirement already satisfied: llama-index-core<0.11.0,>=0.10.1 in /usr/local/lib/python3.10/dist-packages (from llama-index-embeddings-gradient) (0.10.12)
# Requirement already satisfied: aenum>=3.1.11 in /usr/local/lib/python3.10/dist-packages (from gradientai<2.0.0,>=1.5.0->llama-index-embeddings-gradient) (3.1.15)
# Requirement already satisfied: pydantic<2.0.0,>=1.10.5 in /usr/local/lib/python3.10/dist-packages (from gradientai<2.0.0,>=1.5.0->llama-index-embeddings-gradient) (1.10.14)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from gradientai<2.0.0,>=1.5.0->llama-index-embeddings-gradient) (2.8.2)
# Requirement already satisfied: urllib3>=1.25.3 in /usr/local/lib/python3.10/dist-packages (from gradientai<2.0.0,>=1.5.0->llama-index-embeddings-gradient) (2.2.1)
# Requirement already satisfied: PyYAML>=6.0.1 in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-gradient) (6.0.1)
# Requirement already satisfied: SQLAlchemy[asyncio]>=1.4.49 in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-gradient) (2.0.27)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.6 in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-gradient) (3.9.3)
# Requirement already satisfied: dataclasses-json in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-gradient) (0.6.4)
# Requirement already satisfied: deprecated>=1.2.9.3 in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-gradient) (1.2.14)
# Requirement already satisfied: dirtyjson<2.0.0,>=1.0.8 in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-gradient) (1.0.8)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-gradient) (2024.2.0)
# Requirement already satisfied: httpx in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-gradient) (0.27.0)
# Requirement already satisfied: llamaindex-py-client<0.2.0,>=0.1.13 in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-gradient) (0.1.13)
# Requirement already satisfied: nest-asyncio<2.0.0,>=1.5.8 in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-gradient) (1.6.0)
# Requirement already satisfied: networkx>=3.0 in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-gradient) (3.2.1)
# Requirement already satisfied: nltk<4.0.0,>=3.8.1 in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-gradient) (3.8.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-gradient) (1.26.4)
# Requirement already satisfied: openai>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-gradient) (1.12.0)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-gradient) (2.2.0)
# Requirement already satisfied: pillow>=9.0.0 in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-gradient) (10.2.0)
# Requirement already satisfied: requests>=2.31.0 in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-gradient) (2.31.0)
# Requirement already satisfied: tenacity<9.0.0,>=8.2.0 in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-gradient) (8.2.3)
# Requirement already satisfied: tiktoken>=0.3.3 in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-gradient) (0.4.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.66.1 in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-gradient) (4.66.2)
# Requirement already satisfied: typing-extensions>=4.5.0 in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-gradient) (4.9.0)
# Requirement already satisfied: typing-inspect>=0.8.0 in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-gradient) (0.9.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-gradient) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-gradient) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-gradient) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-gradient) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-gradient) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-gradient) (4.0.3)
# Requirement already satisfied: wrapt<2,>=1.10 in /usr/local/lib/python3.10/dist-packages (from deprecated>=1.2.9.3->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-gradient) (1.16.0)
# Requirement already satisfied: anyio in /usr/local/lib/python3.10/dist-packages (from httpx->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-gradient) (4.3.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from httpx->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-gradient) (2024.2.2)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.10/dist-packages (from httpx->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-gradient) (1.0.4)
# Requirement already satisfied: idna in /usr/local/lib/python3.10/dist-packages (from httpx->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-gradient) (3.6)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from httpx->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-gradient) (1.3.0)
# Requirement already satisfied: h11<0.15,>=0.13 in /usr/local/lib/python3.10/dist-packages (from httpcore==1.*->httpx->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-gradient) (0.14.0)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk<4.0.0,>=3.8.1->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-gradient) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk<4.0.0,>=3.8.1->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-gradient) (1.3.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.10/dist-packages (from nltk<4.0.0,>=3.8.1->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-gradient) (2023.12.25)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.10/dist-packages (from openai>=1.1.0->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-gradient) (1.9.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->gradientai<2.0.0,>=1.5.0->llama-index-embeddings-gradient) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.31.0->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-gradient) (3.3.2)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.10/dist-packages (from SQLAlchemy[asyncio]>=1.4.49->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-gradient) (3.0.3)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from typing-inspect>=0.8.0->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-gradient) (1.0.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /usr/local/lib/python3.10/dist-packages (from dataclasses-json->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-gradient) (3.20.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-gradient) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-gradient) (2024.1)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /usr/local/lib/python3.10/dist-packages (from anyio->httpx->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-gradient) (1.2.0)
# Requirement already satisfied: packaging>=17.0 in /usr/local/lib/python3.10/dist-packages (from marshmallow<4.0.0,>=3.18.0->dataclasses-json->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-gradient) (23.2)
# Installing collected packages: llama-index-embeddings-gradient
# Successfully installed llama-index-embeddings-gradient-0.1.2

# %%
from cassandra.auth import PlainTextAuthProvider
from cassandra.cluster import Cluster
from llama_index.core import ServiceContext
from llama_index.core import set_global_service_context
from llama_index.core import VectorStoreIndex, SimpleDirectoryReader, StorageContext
from llama_index.llms.gradient import GradientBaseModelLLM
from llama_index.embeddings.gradient import GradientEmbedding
from llama_index.core import Settings

# %%
import cassandra
print (cassandra.__version__)
# Out:
# 3.29.0

# %%
llm = GradientBaseModelLLM(
    base_model_slug="llama2-7b-chat",
    max_tokens=400,
)

# %%
embed_model = GradientEmbedding(
    gradient_access_token = os.environ["GRADIENT_ACCESS_TOKEN"],
    gradient_workspace_id = os.environ["GRADIENT_WORKSPACE_ID"],
    gradient_model_slug="bge-large",
)

# %%
service_context = ServiceContext.from_defaults(
    llm = llm,
    embed_model = embed_model,
    chunk_size=256,
)

set_global_service_context(service_context)
# Out:
# <ipython-input-23-c6fc8b80050a>:1: DeprecationWarning: Call to deprecated class method from_defaults. (ServiceContext is deprecated, please use `llama_index.settings.Settings` instead.) -- Deprecated since version 0.10.0.
#   service_context = ServiceContext.from_defaults(

# %%
documents = SimpleDirectoryReader("/content/documents").load_data()
print(f"Loaded {len(documents)} document(s).")
# Out:
# Loaded 47 document(s).

# %%
index = VectorStoreIndex.from_documents(documents,
                                        service_context=service_context)
query_engine = index.as_query_engine()

# %%
response = query_engine.query("what is the book about?")
print(response)
# Out:
#  Based on the context provided, the book appears to be about the relationship between two characters, Dahlia and Dylan. The book starts with Dahlia discovering that her mother is a gold digger and her father is not who she thought he was. Dahlia then meets Dylan, who is cold and unSympathetic towards her. They are assigned a project together, where they spend three hours creating a detailed map of Asia. Throughout the project, Dylan is uncooperative and critical towards Dahlia, leading her to wonder why he hates her so much. In the end, Dylan reveals that he finds her annoying and a stuck-up brat, and leaves.
#
# The book seems to explore themes of family, relationships, and self-discovery. It may also touch on the idea of societal expectations and the pressure to conform to certain norms. Overall, the book appears to be a coming-of-age story that delves into the complexities of adolescence and the challenges of navigating personal and social relationships.

# %%
response = query_engine.query("which age-groups can read this book?")
print(response)
# Out:
#  Based on the context provided, the book appears to be written for a middle grade audience, likely targeting readers between the ages of 8-12. The language used is simple and easy to understand, and the storyline is straightforward and relatable for this age group. The characters are also relatable and easy to imagine as friends or classmates, which can help young readers connect with the story. Additionally, the themes of friendship, adventure, and exploration are common in middle grade literature and are likely to appeal to this age group.
